# %%
import pandas as pd

# %%
delinquent = pd.read_csv(
    "/Users/eugeniapark/Documents/coursework/W9/Coursework-Technical-Business-Analyst-Week-1/data/delinquent_accounts_export.csv")

# %%
delinquent.value_counts()
# Out:
# account_id  customer_id  customer_name        product_type   delinquency_stage  days_past_due  overdue_amount  total_balance  risk_flag  current_status      email                       mobile_phone  postcode  last_contact_channel  self_service_candidate  created_date
# ACC-10175   CUST-50175   Conor Taylor-Moore   auto_finance   mid                59             817.10          3409.38        Y          Awaiting Follow Up  joycetaylor@example.org     5.879995e+10  E8D 7RT   phone                 N                       2025-12-07      2
# ACC-10293   CUST-50293   Mohamed Price        personal_loan  early              16             440.63          12616.24       N          awaiting_follow_up  neilbirch@example.org       6.242809e+10  TA4H 9JA  email                 Y                       2026-01-01      2
# ...

# %%
delinquent.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3246 entries, 0 to 3245
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   account_id              3246 non-null   str
#  1   customer_id             3246 non-null   str
#  2   customer_name           3246 non-null   str
#  3   product_type            3246 non-null   str
#  4   delinquency_stage       3246 non-null   str
#  5   days_past_due           3246 non-null   int64
#  6   overdue_amount          3246 non-null   float64
#  7   total_balance           3246 non-null   float64
#  8   risk_flag               3246 non-null   str
#  9   current_status          3177 non-null   str
#  10  email                   3076 non-null   str
#  11  mobile_phone            3068 non-null   float64
#  12  postcode                3246 non-null   str
#  13  last_contact_channel    2594 non-null   str
#  14  self_service_candidate  3246 non-null   str
# ...

# %%
delinquent["self_service_candidate"].value_counts()
# Out:
# self_service_candidate
# Y      2507
# N       720
# No       10
# Yes       9
# Name: count, dtype: int64

# %%
delinquent["created_date"] = pd.to_datetime(delinquent["created_date"])

monthly_counts = delinquent["created_date"].dt.to_period(
    'M').value_counts().sort_index()

print(monthly_counts)
# Out:
# created_date
# 2025-10    791
# 2025-11    830
# 2025-12    810
# 2026-01    815
# Freq: M, Name: count, dtype: int64

# %%
activity_tracker = pd.read_csv(
    "/Users/eugeniapark/Documents/coursework/W9/Coursework-Technical-Business-Analyst-Week-1/data/recovery_activity_tracker.csv")

# %%
activity_tracker["straightforward"] = activity_tracker["self_service_candidate"].isin(["Y", "Yes"])
